# %%
# Activity 4: Data Quality Automation Tools

# Task A: Using Great Expectations

# 19. Setting Up Expectations:
# - Install Great Expectations and set up a basic expectation suite.
# - Validate a dataset and list unmet expectations.






# 20. Testing for Expectation:
# - Create expectations such as “column values must fall within a certain range.”






# 21. Generating Data Docs:
# - Automatically generate data quality documentation.

# %%
# !pip install great_expectations
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !great_expectations init
# Out:
# /bin/bash: line 1: great_expectations: command not found

# %%
import pandas as pd
from great_expectations.data_context import get_context
from great_expectations.expectations.expectation_configuration import ExpectationConfiguration
from great_expectations.validator.validator import Validator
from great_expectations.core.batch import RuntimeBatchRequest

# 1. Load your data
df = pd.read_csv("/workspaces/AI_DATA_ANALYSIS_/src/Module 3/Techniques to Improve Data Quality/sales_data.csv")

# 2. Get the data context (assumes you've already done `great_expectations init`)
context = get_context()

# 3. Define a RuntimeBatchRequest
batch_request = RuntimeBatchRequest(
    datasource_name="my_pandas_datasource",  # Define this first or use 'default_pandas_datasource'
    data_connector_name="default_runtime_data_connector_name",
    data_asset_name="sales_data",
    runtime_parameters={"batch_data": df},
    batch_identifiers={"default_identifier_name": "default_id"},
)

# 4. Create an Expectation Suite
suite_name = "demo_suite"
context.create_expectation_suite(expectation_suite_name=suite_name, overwrite_existing=True)

# 5. Get a Validator
validator: Validator = context.get_validator(
    batch_request=batch_request,
    expectation_suite_name=suite_name,
)

# 6. Add expectations
validator.expect_column_values_to_not_be_null("age")
validator.expect_column_values_to_be_between("age", min_value=0, max_value=120)

# 7. Save and validate
validator.save_expectation_suite(discard_failed_expectations=False)
results = validator.validate()
print(results)

# 8. Generate Data Docs
context.build_data_docs()
context.open_data_docs()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 24
#      22 # 4. Create an Expectation Suite
#      23 suite_name = "demo_suite"
# ---> 24 context.create_expectation_suite(expectation_suite_name=suite_name, overwrite_existing=True)
#      26 # 5. Get a Validator
#      27 validator: Validator = context.get_validator(
#      28     batch_request=batch_request,
#      29     expectation_suite_name=suite_name,
#      30 )
#
# AttributeError: 'EphemeralDataContext' object has no attribute 'create_expectation_suite'

# %%
# Task B: Using DQ Labs

# 22. Tool Setup and Configuration:
# - Download and configure DQ Labs on your local environment.
# - Create a new data quality project.








# 23. Data Analysis Automation:
# - Apply DQ Labs for automating data profiling and quality checks.







# 24. Quality Rule Creation:
# - Create quality rules for detecting and handling duplicates or enforcing standards.

# %%
# !pip install great_expectations pandas pandas-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 1.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 6.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 28.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 46.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 39.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.1/511.1 kB 36.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 44.6 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 47.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 30.2 MB/s eta 0:00:0000:010:01m
# ...

# %%
# !great_expectations init
# Out:
# /bin/bash: line 1: great_expectations: command not found

# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv("/workspaces/AI_DATA_ANALYSIS_/src/Module 3/Techniques to Improve Data Quality/employees.csv")
# Generate profile
profile = ProfileReport(df, title="Data Profiling Report", explorative=True)
profile.to_file("profiling_report.html")
# Out:
# ...
# Summarize dataset:  45%|████▌     | 5/11 [00:00<00:00, 68.15it/s, Describe variable: email]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3119/1453092807.py in ?()
#       3
#       4 df = pd.read_csv("/workspaces/AI_DATA_ANALYSIS_/src/Module 3/Techniques to Improve Data Quality/employees.csv")
#       5 # Generate profile
#       6 profile = ProfileReport(df, title="Data Profiling Report", explorative=True)
# ----> 7 profile.to_file("profiling_report.html")
#
# ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self, output_file, silent)
#     377                 if self.config.html.assets_prefix is None:
#     378                     self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     379                 create_html_assets(self.config, output_file)
#     380
# --> 381             data = self.to_html()
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load data
df = pd.read_csv("/workspaces/AI_DATA_ANALYSIS_/src/Module 3/Techniques to Improve Data Quality/employees.csv")

# Disable problematic stats
profile = ProfileReport(
    df,
    title="Data Profiling Report",
    explorative=True,
    config={
        "vars": {
            "num": {"chi_squared_threshold": 0.0},  # Disable Chi-squared for numerical
            "cat": {"chi_squared": False},          # Disable Chi-squared for categorical
        }
    }
)

# Export report
profile.to_file("profiling_report.html")
# Out:
# ---------------------------------------------------------------------------
# TypeCheckError                            Traceback (most recent call last)
# Cell In[7], line 8
#       5 df = pd.read_csv("/workspaces/AI_DATA_ANALYSIS_/src/Module 3/Techniques to Improve Data Quality/employees.csv")
#       7 # Disable problematic stats
# ----> 8 profile = ProfileReport(
#       9     df,
#      10     title="Data Profiling Report",
#      11     explorative=True,
#      12     config={
#      13         "vars": {
#      14             "num": {"chi_squared_threshold": 0.0},  # Disable Chi-squared for numerical
#      15             "cat": {"chi_squared": False},          # Disable Chi-squared for categorical
#      16         }
#      17     }
#      18 )
#      20 # Export report
#      21 profile.to_file("profiling_report.html")
#
# ...
