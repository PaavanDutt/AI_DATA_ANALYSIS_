# %%
# Question: Winsorization of Data
# Description: Apply Winsorization to a given dataset to handle outliers.

import numpy as np
from scipy.stats.mstats import winsorize
import matplotlib.pyplot as plt

# Sample data with outliers
data = np.array([1, 2, 2, 3, 4, 5, 6, 100])

# Apply Winsorization: limit bottom and top 10%
winsorized_data = winsorize(data, limits=[0.1, 0.1])


print("Original Data:", data)
print("Winsorized Data:", winsorized_data)

# Visualize
plt.figure(figsize=(8,4))
plt.boxplot([data, winsorized_data], labels=['Original', 'Winsorized'])
plt.title("Boxplot Before and After Winsorization")
plt.show()
# Out:
# Original Data: [  1   2   2   3   4   5   6 100]
# Winsorized Data: [  1   2   2   3   4   5   6 100]
# /tmp/ipykernel_1772/4266952275.py:20: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data, winsorized_data], labels=['Original', 'Winsorized'])
