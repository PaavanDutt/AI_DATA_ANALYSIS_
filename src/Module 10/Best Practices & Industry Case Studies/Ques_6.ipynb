# %% [markdown]
# ### Basic ML Model Monitoring with MLFlow
# **Description**: Set up a basic ML model monitoring pipeline using MLFlow to track experiment parameters and results.
#
# **Steps**:
# 1. Installation
# 2. Set Up MLFlow Tracking
# 3. Training a Simple Model
# 4. Logging Model and Metrics
# 5. View Logged Data
#     - Access the MLFlow UI to view your logged parameters, metrics, and models.

# %%
# 1. Installation (run in your terminal, not in script)
# pip install mlflow scikit-learn

import mlflow
import mlflow.sklearn
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# 2. Set up MLflow experiment
mlflow.set_experiment("basic-ml-monitoring")

with mlflow.start_run():
    # 3. Load data and train model
    iris = load_iris()
    X_train, X_test, y_train, y_test = train_test_split(
        iris.data, iris.target, test_size=0.3, random_state=42
    )
    n_estimators = 100
    max_depth = 3
    model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=42)
    model.fit(X_train, y_train)

    # 4. Predict and evaluate
    preds = model.predict(X_test)
    acc = accuracy_score(y_test, preds)

    # Log parameters
    mlflow.log_param("n_estimators", n_estimators)
    mlflow.log_param("max_depth", max_depth)

    # Log metrics
    mlflow.log_metric("accuracy", acc)

    # Log model
    mlflow.sklearn.log_model(model, "random_forest_model")

    print(f"Model trained with accuracy: {acc:.4f}")
    print("Run ID:", mlflow.active_run().info.run_id)

# 5. To view logged data:
# Run this command in your terminal (in the folder where you run this script):
# mlflow ui
# Then open your browser at http://localhost:5000 to explore your experiments

# write your code from here
# Out:
# 2025/05/28 14:17:49 INFO mlflow.tracking.fluent: Experiment with name 'basic-ml-monitoring' does not exist. Creating a new experiment.
# 2025/05/28 14:17:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model trained with accuracy: 1.0000
# Run ID: 9f214f4b0ab64f1180bda2c3a5bc38d8

# %%
# !pip install mlflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlflow
#   Downloading mlflow-2.22.0-py3-none-any.whl (29.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 18.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<3 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.26.4)
# Collecting markdown<4,>=3.3
#   Downloading markdown-3.8-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 13.6 MB/s eta 0:00:00
# Collecting pyarrow<20,>=4.0.0
#   Downloading pyarrow-19.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 13.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scikit-learn<2 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: Flask<4 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: pandas<3 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (2.1.4)
# Requirement already satisfied: gunicorn<24 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (23.0.0)
# Collecting docker<8,>=4.0.0
#   Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 26.4 MB/s eta 0:00:00
# Collecting graphene<4
#   Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.4.54)
# Requirement already satisfied: scipy<2 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.15.3)
# Collecting mlflow-skinny==2.22.0
#   Downloading mlflow_skinny-2.22.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 24.4 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (1.16.1)
# Requirement already satisfied: matplotlib<4 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (3.10.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (2.32.3)
# Requirement already satisfied: fastapi<1 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.115.12)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (2.11.5)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (5.29.4)
# Requirement already satisfied: uvicorn<1 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.34.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (5.5.2)
# Requirement already satisfied: packaging<25 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (24.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.5.3)
# Collecting databricks-sdk<1,>=0.20.0
#   Downloading databricks_sdk-0.55.0-py3-none-any.whl (722 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.9/722.9 kB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.44)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (4.13.2)
# Requirement already satisfied: click<9,>=7.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (8.2.1)
# Collecting cloudpickle<4
#   Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.33.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.33.1)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from mlflow-skinny==2.22.0->mlflow) (8.6.1)
# Requirement already satisfied: Mako in /home/vscode/.local/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: tomli in /home/vscode/.local/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (2.2.1)
# Requirement already satisfied: urllib3>=1.26.0 in /home/vscode/.local/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (2.4.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /home/vscode/.local/lib/python3.10/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from Flask<4->mlflow) (3.0.6)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Collecting graphql-relay<3.3,>=3.1
#   Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Collecting graphql-core<3.3,>=3.1
#   Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 31.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow) (3.0.2)
# Requirement already satisfied: pillow>=8 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (11.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.58.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.2)
# Collecting google-auth~=2.0
#   Downloading google_auth-2.40.2-py2.py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.1/216.1 kB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/vscode/.local/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==2.22.0->mlflow) (0.46.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /home/vscode/.local/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in /home/vscode/.local/lib/python3.10/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /home/vscode/.local/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (0.54b1)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/vscode/.local/lib/python3.10/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.4.0)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (2025.4.26)
# Requirement already satisfied: h11>=0.8 in /home/vscode/.local/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==2.22.0->mlflow) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/vscode/.local/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (5.0.2)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/vscode/.local/lib/python3.10/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /home/vscode/.local/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/vscode/.local/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.3.0)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 18.3 MB/s eta 0:00:00
# Installing collected packages: pyasn1, pyarrow, markdown, graphql-core, cloudpickle, rsa, pyasn1-modules, graphql-relay, docker, graphene, google-auth, databricks-sdk, mlflow-skinny, mlflow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 20.0.0
#     Uninstalling pyarrow-20.0.0:
#       Successfully uninstalled pyarrow-20.0.0
# Successfully installed cloudpickle-3.1.1 databricks-sdk-0.55.0 docker-7.1.0 google-auth-2.40.2 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 markdown-3.8 mlflow-2.22.0 mlflow-skinny-2.22.0 pyarrow-19.0.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
