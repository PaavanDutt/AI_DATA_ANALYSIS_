# %% [markdown]
# ## Validate Data Completeness for Critical Fields
#
# **Description**: In `transaction_data.csv` , calculate the missing percentage of critical fields: "transaction_id", "amount", and "date", and visualize them.

# %%
# Write your code from here

import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('transaction_data.csv')

# Define critical fields
critical_fields = ['transaction_id', 'amount', 'date']

# Calculate missing percentages
missing_percentages = df[critical_fields].isnull().mean() * 100

# Print missing percentage for each field
print("Missing Data Percentages:")
print(missing_percentages)

# Plot missing percentages
plt.figure(figsize=(8, 5))
missing_percentages.plot(kind='bar', color='salmon', edgecolor='black')
plt.title('Missing Data Percentage for Critical Fields')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=45)
plt.ylim(0, 100)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Missing Data Percentages:
# transaction_id    20.0
# amount            30.0
# date              10.0
# dtype: float64

# %%
import pandas as pd
import numpy as np

# Sample data
data = {
    'transaction_id': [1001, 1002, 1003, None, 1005, 1006, 1007, 1008, None, 1010],
    'amount': [250.50, None, 399.99, 100.00, None, 300.00, 200.00, 150.00, 500.00, None],
    'date': ['2023-01-15', '2023-01-16', None, '2023-01-18', '2023-01-19',
             '2023-01-20', '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24'],
    'customer_id': [501, 502, 503, 504, 505, 506, 507, 508, 509, 510]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save as CSV
df.to_csv('transaction_data.csv', index=False)

print("Sample dataset 'transaction_data.csv' has been created locally.")
# Out:
# Sample dataset 'transaction_data.csv' has been created locally.
